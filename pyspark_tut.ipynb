# %%
'''PySpark Dataframe
Reading The Dataset
Checking the Datatypes of the Column(Schema)
Selecting Columns And Indexing
Check Describe option similar to Pandas
Adding Columns
Dropping columns
Renaming Columns'''
# Out:
# 'PySpark Dataframe\nReading The Dataset\nChecking the Datatypes of the Column(Schema)\nSelecting Columns And Indexing\nCheck Describe option similar to Pandas\nAdding Columns\nDropping columns\nRenaming Columns'

# %%
pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/310.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/310.8 MB 1.7 MB/s eta 0:03:09
#      ---------------------------------------- 0.1/310.8 MB 1.3 MB/s eta 0:03:57
#      ---------------------------------------- 0.2/310.8 MB 1.3 MB/s eta 0:03:57
#      ---------------------------------------- 0.2/310.8 MB 1.1 MB/s eta 0:04:31
#      ---------------------------------------- 0.3/310.8 MB 1.3 MB/s eta 0:04:05
#      ---------------------------------------- 0.4/310.8 MB 1.5 MB/s eta 0:03:25
#      ---------------------------------------- 0.5/310.8 MB 1.4 MB/s eta 0:03:40
#      ---------------------------------------- 0.6/310.8 MB 1.5 MB/s eta 0:03:26
#      ---------------------------------------- 0.6/310.8 MB 1.5 MB/s eta 0:03:29
#      ---------------------------------------- 0.6/310.8 MB 1.5 MB/s eta 0:03:26
#      ---------------------------------------- 0.6/310.8 MB 1.5 MB/s eta 0:03:26
# ...

# %%
import pyspark

# %%
import findspark 
findspark.init()
findspark.find()
# Out:
# 'C:\\spark\\spark-3.4.1-bin-hadoop3'

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('app1').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-IANC001.mshome.net:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>app1</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#read the dataset
df_pyspark=spark.read.csv(r'D:\Naresh_it_praksah_senapathi\sept_DL\Spark\sample.csv')

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
df_pyspark.show()
# Out:
# +------+---+
# |   _c0|_c1|
# +------+---+
# | Name |Age|
# |Michel| 30|
# |  John| 32|
# |   Max| 33|
# +------+---+

# %%
#need to remove the c0 and c1 and replace with the name
df_pyspark1=spark.read.option('header','true').csv(r'D:\Naresh_it_praksah_senapathi\sept_DL\Spark\sample.csv',inferSchema=True)

# %%
df_pyspark1
# Out:
# DataFrame[Name : string, Age: int]

# %%
df_pyspark1.show()
# Out:
# +------+---+
# | Name |Age|
# +------+---+
# |Michel| 30|
# |  John| 32|
# |   Max| 33|
# +------+---+

# %%
type(df_pyspark1)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark1.head()
# Out:
# Row(Name ='Michel', Age=30)

# %%
df_pyspark1.head(10)
# Out:
# [Row(Name ='Michel', Age=30),
#  Row(Name ='John', Age=32),
#  Row(Name ='Max', Age=33)]

# %%
df_pyspark1.printSchema()
# Out:
# root
#  |-- Name : string (nullable = true)
#  |-- Age: integer (nullable = true)

# %%
df_pyspark1.show()
# Out:
# +------+---+
# | Name |Age|
# +------+---+
# |Michel| 30|
# |  John| 32|
# |   Max| 33|
# +------+---+

# %%
df_pyspark1.show()
# Out:
# +------+---+
# | Name |Age|
# +------+---+
# |Michel| 30|
# |  John| 32|
# |   Max| 33|
# +------+---+

# %%
df_pyspark1.head(3)
# Out:
# [Row(Name ='Michel', Age=30),
#  Row(Name ='John', Age=32),
#  Row(Name ='Max', Age=33)]

# %%
df_pyspark1.dtypes
# Out:
# [('Name ', 'string'), ('Age', 'int')]
